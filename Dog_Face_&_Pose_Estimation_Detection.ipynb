# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
HOME = "/content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection"
print(HOME)
# Out:
# /content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection

# %%
# %cd /content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection
# Out:
# /content/drive/MyDrive/Dog Face & Pose Estimation Detection

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325 (from 1)
# Receiving objects: 100% (325/325), 2.25 MiB | 5.75 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# /content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/yolov9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.8 MB/s eta 0:00:00

# %%
# %cd {HOME}

# !python yolov9/train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg yolov9/models/detect/gelan-c.yaml \
--hyp yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# /content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection
# 2024-12-11 11:04:13.578638: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-11 11:04:13.598063: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-11 11:04:13.604007: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-11 11:04:13.618110: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %% [markdown]
# # Training Results

# %%
from IPython.display import Image

Image(filename=f"/content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/yolov9/runs/train/exp/results.png", width=1000)

# %%
# !python yolov9/detect.py \
--img 1280 --conf 0.25 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source /content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/yolov9/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/test/images, data=yolov9/data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# # Results

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'/content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/yolov9/runs/detect/exp3/img1878_png.rf.e8f69bbe68a193a2b44a3b7027074797.jpg')[:10]:
      display(Image(filename=image_path, width=600))

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'/content/drive/MyDrive/Dog_Face_and_Pose_Estimation_Detection/yolov9/runs/detect/exp3/img2330_png.rf.df37e585fa246d3ff6059023085f4206.jpg')[:10]:
      display(Image(filename=image_path, width=600))
